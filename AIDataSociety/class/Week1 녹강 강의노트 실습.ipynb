# %%
# Practice 1

print("Hello AI")

print(1+2)
print(10+20)
2**10

# Practice 2
# matplotlib 시각화

import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range( len(ys))]

plt.plot(x,ys,'-')
plt.fill_between(x,ys,195, where = (ys>=195), facecolor = 'g', alpha = 0.6)

plt.title("Sample Visualization")
plt.show()

# Practice 3
y = input("몇 년도에 태어났나요?")
print("당신의 나이는 ", 2021 - int(y), "이군요")

# Practice 4
sum = 0

for i in range (11):
  print(i)
  sum += i

print("sum = ", sum)
# Out:
# Hello AI
# 3
# 30
# 1024
