# %%
txt = 'System AI Data Information AI SCIence Analysis Data'
from wordcloud import WordCloud
wc_output = WordCloud(width=1500, height=1000).generate(txt)
import matplotlib.pyplot as plt
plt.imshow(wc_output)

# %%
# Wikipedia AI
from wordcloud import WordCloud
from wordcloud import STOPWORDS #불용어 삭제
from google.colab import files
import matplotlib.pyplot as plt
files.upload()

#임의의 불용어 추가
STOPWORDS = STOPWORDS.union(['AI', 'human']) #리스트, 중괄호 가능

f=open('AI_Wiki.txt', 'r', encoding='UTF8')
text = f.read()

wordcloud = WordCloud(width=1500, height=1000, stopwords=STOPWORDS).generate(text) #불용어 삭제 
# figsize, 랑 위의 크기 차이는 무엇? 위는 해상도. 해상도가 크다고 크게 보이진 않음. 밑에서 크기 조절
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off') #축 삭제
plt.show()

#파일 저장
wc_output.to_file('ai_worldcloud_image.jpg')

#파일 다운로드
wc_output.download('ai_worldcloud_image.jpg')
# Out:
#      <input type="file" id="files-fd703cd8-0bfd-479b-aba7-561e597fb743" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd703cd8-0bfd-479b-aba7-561e597fb743">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f64493fc0169> in <module>()
#       1 # Wikipedia AI
#       2 from google.colab import files
# ----> 3 files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
# 한글 wordcloud
# 1. 한글 폰트 설치
'''
# !sudo apt install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
'''
# 2. 런타임 다시시작

# Wikipedia AI
from wordcloud import WordCloud
from wordcloud import STOPWORDS #불용어 삭제
from google.colab import files
import matplotlib.pyplot as plt
files.upload()

#임의의 불용어 추가
STOPWORDS = STOPWORDS.union(['있다', '있는']) #리스트, 중괄호 가능

f=open('AI_위키.txt', 'r', encoding='UTF8')
text = f.read()

#한글 텍스트파일 경로
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
wordcloud = WordCloud(width=1500, height=1000, stopwords=STOPWORDS, font_path=path).generate(text) #불용어 삭제, 한글 적용
# figsize, 랑 위의 크기 차이는 무엇? 위는 해상도. 해상도가 크다고 크게 보이진 않음. 밑에서 크기 조절
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off') #축 삭제
plt.show()

#파일 저장
wc_output.to_file('ai_worldcloud_image.jpg')

#파일 다운로드
wc_output.download('ai_worldcloud_image.jpg')

# %%
# 이미지 마스크 활용
# 1. 이미지 필요 (검정 모양에 하얀 바탕만 가능)
from wordcloud import WordCloud
from wordcloud import STOPWORDS #불용어 삭제
from google.colab import files
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# 마스크파일 읽기
maskHeart = np.array(Image.open('heart_mask.jpg'))
files.upload()

#임의의 불용어 추가
STOPWORDS = STOPWORDS.union(['있다', '있는']) #리스트, 중괄호 가능

f=open('AI_위키.txt', 'r', encoding='UTF8')
text = f.read()

#한글 텍스트파일 경로
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
wordcloud = WordCloud(width=1500, height=1000, stopwords=STOPWORDS, font_path=path mask= maskHeart, background_color='white').generate(text) #불용어 삭제, 한글 적용, 마스크 적용, 배경색 변경
# figsize, 랑 위의 크기 차이는 무엇? 위는 해상도. 해상도가 크다고 크게 보이진 않음. 밑에서 크기 조절
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off') #축 삭제
plt.show()

#파일 저장
wc_output.to_file('ai_worldcloud_image.jpg')

#파일 다운로드
wc_output.download('ai_worldcloud_image.jpg')
