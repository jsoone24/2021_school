# %%
sum =0
for i in range(11):
  sum += i

print(sum)

a = [20,3,4,45,30,302,2,304,0,4,3,4,2]

for v in range(len(a)):
  print(a[v])

print()

for v in a:
  print(v)

# 빈 리스트 생성
# 사용자에게 점수를 입력하세요 : 라고 묻습니다.
# 점수를 리스트 추가합니다.
# 다 추가되면 모든 점수를 출력합니다.
# while 문 사용 - x를 입력하기 전까지 반복

l = []
i = input("점수를 입력하세요 : ")
while i != 'x':
  l.append(i)
  i = input("점수를 입력하세요 : ")

for v in l:
  print("점수:", v)

import seaborn as s
d = s.load_dataset('titanic')
d

s.countplot(data=d, x='alive')
# Out:
# 55
# 20
# 3
# 4
# 45
# 30
# 302
# 2
# 304
# 0
# 4
# 3
# 4
# 2
#
# 20
# 3
# 4
# 45
# 30
# 302
# 2
# 304
# 0
# 4
# 3
# 4
# 2
# 점수:
# 점수:
# 점수:
# 점수:
# 점수:
# 점수:
# 점수:
# 점수:
# <AxesSubplot:xlabel='alive', ylabel='count'>
